# %%
# Make sure that you have all these libaries available to run the code successfully
from pandas_datareader import data
import matplotlib.pyplot as plt
import pandas as pd
import datetime as dt
import urllib.request, json
import os
import numpy as np
import tensorflow as tf # This code has been tested with TensorFlow 1.6
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# API_Key = "EFLQGAB7KKG76G6I"

# %%
# !pwd
# Out:
# /content

# %%
# !ls
# Out:
# sample_data

# %%
# !cd sample_data/

# %%
# !ls
# Out:
# sample_data

# %%
data_source = 'kaggle' # alphavantage or kaggle

if data_source == 'alphavantage':
    # ====================== Loading Data from Alpha Vantage ==================================

    api_key = 'EFLQGAB7KKG76G6I'

    # Advanced Micro Devices stock market prices
    ticker = "AMD"

    # JSON file with all the stock market data for AMD from the last 20 years
    url_string = "https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=%s&outputsize=full&apikey=%s"%(ticker,api_key)

    # Save data to this file
    file_to_save = 'stock_market_data-%s.csv'%ticker

    # If you haven't already saved data,
    # Go ahead and grab the data from the url
    # And store date, low, high, volume, close, open values to a Pandas DataFrame
    if not os.path.exists(file_to_save):
        with urllib.request.urlopen(url_string) as url:
            data = json.loads(url.read().decode())
            # extract stock market data
            data = data['Time Series (Daily)']
            df = pd.DataFrame(columns=['Date','Low','High','Close','Open'])
            for k,v in data.items():
                date = dt.datetime.strptime(k, '%Y-%m-%d')
                data_row = [date.date(),float(v['3. low']),float(v['2. high']),
                            float(v['4. close']),float(v['1. open'])]
                df.loc[-1,:] = data_row
                df.index = df.index + 1
        print('Data saved to : %s'%file_to_save)        
        df.to_csv(file_to_save)

    # If the data is already there, just load it from the CSV
    else:
        print('File already exists. Loading data from CSV')
        df = pd.read_csv(file_to_save)

else:

    # ====================== Loading Data from Kaggle ==================================
    # You will be using HP's data. Feel free to experiment with other data.
    # But while doing so, be careful to have a large enough dataset and also pay attention to the data normalization
    df = pd.read_csv(os.path.join('sample_data','amd.us.txt'),delimiter=',',usecols=['Date','Open','High','Low','Close'])
    print('Loaded data from the Kaggle repository')
# Out:
# Loaded data from the Kaggle repository

# %%
df.head()
# Out:
#          Date  Open  High   Low  Close
# 0  1983-03-21  8.97  9.03  8.81   9.00
# 1  1983-03-22  8.72  8.97  8.50   8.50
# 2  1983-03-23  8.50  8.81  8.47   8.72
# 3  1983-03-24  8.72  8.78  8.66   8.78
# 4  1983-03-25  8.91  9.06  8.75   8.88

# %%
df.tail()
# Out:
#             Date   Open   High     Low  Close
# 8732  2017-11-06  12.04  12.09  11.640  11.93
# 8733  2017-11-07  11.94  12.27  11.940  12.05
# 8734  2017-11-08  11.94  11.95  11.510  11.71
# 8735  2017-11-09  11.25  11.35  11.030  11.12
# 8736  2017-11-10  11.22  11.43  11.115  11.26

# %%
# !ls
# Out:
# sample_data

# %%
# !ls sample_data/
# Out:
# amd.us.txt     california_housing_test.csv   mnist_test.csv	    README.md
# anscombe.json  california_housing_train.csv  mnist_train_small.csv

# %%
# Sort DataFrame by date
df = df.sort_values('Date')

# Double check the result
df.head()
df.shape
# Out:
# (8737, 5)

# %%
plt.figure(figsize = (18,9))
plt.plot(range(df.shape[0]),(df['Low']+df['High'])/2.0)
plt.xticks(range(0,df.shape[0],500),df['Date'].loc[::500],rotation=45)
plt.xlabel('Date',fontsize=18)
plt.ylabel('Mid Price',fontsize=18)
plt.show()

# %%
# First calculate the mid prices from the highest and lowest
high_prices = df.loc[:,'High'].as_matrix()
low_prices = df.loc[:,'Low'].as_matrix()
mid_prices = (high_prices+low_prices)/2.0

# %%
train_data = mid_prices[:8000]
test_data = mid_prices[8000:]

# %%
# Scale the data to be between 0 and 1
# When scaling remember! You normalize both test and train data with respect to training data
# Because you are not supposed to have access to test data
scaler = MinMaxScaler()
train_data = train_data.reshape(-1,1)
test_data = test_data.reshape(-1,1)

# %%
# Train the Scaler with training data and smooth data
smoothing_window_size = 400
for di in range(0,8000,smoothing_window_size):
    scaler.fit(train_data[di:di+smoothing_window_size,:])
    train_data[di:di+smoothing_window_size,:] = scaler.transform(train_data[di:di+smoothing_window_size,:])

# You normalize the last bit of remaining data
scaler.fit(train_data[di+smoothing_window_size:,:])
train_data[di+smoothing_window_size:,:] = scaler.transform(train_data[di+smoothing_window_size:,:])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-53-bbe8fd748f55> in <module>()
#       5
#       6 # You normalize the last bit of remaining data
# ----> 7 scaler.fit(train_data[di+smoothing_window_size:,:])
#       8 train_data[di+smoothing_window_size:,:] = scaler.transform(train_data[di+smoothing_window_size:,:])
#
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/data.py in fit(self, X, y)
#     332         # Reset internal state before fitting
#     333         self._reset()
# --> 334         return self.partial_fit(X, y)
#     335
#     336     def partial_fit(self, X, y=None):
#
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/data.py in partial_fit(self, X, y)
#     360         X = check_array(X, copy=self.copy, warn_on_dtype=True,
#     361                         estimator=self, dtype=FLOAT_DTYPES,
# --> 362                         force_all_finite="allow-nan")
#     363
#     364         data_min = np.nanmin(X, axis=0)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     580                              " minimum of %d is required%s."
#     581                              % (n_samples, shape_repr, ensure_min_samples,
# --> 582                                 context))
#     583
#     584     if ensure_min_features > 0 and array.ndim == 2:
#
# ValueError: Found array with 0 sample(s) (shape=(0, 1)) while a minimum of 1 is required by MinMaxScaler.

# %%
# Reshape both train and test data
train_data = train_data.reshape(-1)

# Normalize test data
test_data = scaler.transform(test_data).reshape(-1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-363b3f06678d> in <module>()
#       2
#       3 # Normalize test data
# ----> 4 test_data = scaler.transform(test_data).reshape(-1)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/data.py in transform(self, X)
#     394
#     395         X = check_array(X, copy=self.copy, dtype=FLOAT_DTYPES,
# --> 396                         force_all_finite="allow-nan")
#     397
#     398         X *= self.scale_
#
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     580                              " minimum of %d is required%s."
#     581                              % (n_samples, shape_repr, ensure_min_samples,
# --> 582                                 context))
#     583
#     584     if ensure_min_features > 0 and array.ndim == 2:
#
# ValueError: Found array with 0 sample(s) (shape=(0, 1)) while a minimum of 1 is required.

# %%
# Now perform exponential moving average smoothing
# So the data will have a smoother curve than the original ragged data
EMA = 0.0
gamma = 0.1
for ti in range(8000):
  EMA = gamma*train_data[ti] + (1-gamma)*EMA
  train_data[ti] = EMA

# Used for visualization and test purposes
all_mid_data = np.concatenate([train_data,test_data],axis=0)

# %%
window_size = 100
N = train_data.size
std_avg_predictions = []
std_avg_x = []
mse_errors = []

for pred_idx in range(window_size,N):

    if pred_idx >= N:
        date = dt.datetime.strptime(k, '%Y-%m-%d').date() + dt.timedelta(days=1)
    else:
        date = df.loc[pred_idx,'Date']

    std_avg_predictions.append(np.mean(train_data[pred_idx-window_size:pred_idx]))
    mse_errors.append((std_avg_predictions[-1]-train_data[pred_idx])**2)
    std_avg_x.append(date)

print('MSE error for standard averaging: %.5f'%(0.5*np.mean(mse_errors)))
# Out:
# MSE error for standard averaging: 0.01698

# %%
plt.figure(figsize = (18,9))
plt.plot(range(df.shape[0]),all_mid_data,color='b',label='True')
plt.plot(range(window_size,N),std_avg_predictions,color='orange',label='Prediction')
#plt.xticks(range(0,df.shape[0],50),df['Date'].loc[::50],rotation=45)
plt.xlabel('Date')
plt.ylabel('Mid Price')
plt.legend(fontsize=18)
plt.show()

# %%
window_size = 100
N = train_data.size

run_avg_predictions = []
run_avg_x = []

mse_errors = []

running_mean = 0.0
run_avg_predictions.append(running_mean)

decay = 0.5

for pred_idx in range(1,N):

    running_mean = running_mean*decay + (1.0-decay)*train_data[pred_idx-1]
    run_avg_predictions.append(running_mean)
    mse_errors.append((run_avg_predictions[-1]-train_data[pred_idx])**2)
    run_avg_x.append(date)

print('MSE error for EMA averaging: %.5f'%(0.5*np.mean(mse_errors)))
# Out:
# MSE error for EMA averaging: 0.00008

# %%
plt.figure(figsize = (18,9))
plt.plot(range(df.shape[0]),all_mid_data,color='b',label='True')
plt.plot(range(0,N),run_avg_predictions,color='orange', label='Prediction')
#plt.xticks(range(0,df.shape[0],50),df['Date'].loc[::50],rotation=45)
plt.xlabel('Date')
plt.ylabel('Mid Price')
plt.legend(fontsize=18)
plt.show()

# %%
class DataGeneratorSeq(object):

    def __init__(self,prices,batch_size,num_unroll):
        self._prices = prices
        self._prices_length = len(self._prices) - num_unroll
        self._batch_size = batch_size
        self._num_unroll = num_unroll
        self._segments = self._prices_length //self._batch_size
        self._cursor = [offset * self._segments for offset in range(self._batch_size)]

    def next_batch(self):

        batch_data = np.zeros((self._batch_size),dtype=np.float32)
        batch_labels = np.zeros((self._batch_size),dtype=np.float32)

        for b in range(self._batch_size):
            if self._cursor[b]+1>=self._prices_length:
                #self._cursor[b] = b * self._segments
                self._cursor[b] = np.random.randint(0,(b+1)*self._segments)

            batch_data[b] = self._prices[self._cursor[b]]
            batch_labels[b]= self._prices[self._cursor[b]+np.random.randint(0,5)]

            self._cursor[b] = (self._cursor[b]+1)%self._prices_length

        return batch_data,batch_labels

    def unroll_batches(self):

        unroll_data,unroll_labels = [],[]
        init_data, init_label = None,None
        for ui in range(self._num_unroll):

            data, labels = self.next_batch()    

            unroll_data.append(data)
            unroll_labels.append(labels)

        return unroll_data, unroll_labels

    def reset_indices(self):
        for b in range(self._batch_size):
            self._cursor[b] = np.random.randint(0,min((b+1)*self._segments,self._prices_length-1))



dg = DataGeneratorSeq(train_data,5,5)
u_data, u_labels = dg.unroll_batches()

for ui,(dat,lbl) in enumerate(zip(u_data,u_labels)):   
    print('\n\nUnrolled index %d'%ui)
    dat_ind = dat
    lbl_ind = lbl
    print('\tInputs: ',dat )
    print('\n\tOutput:',lbl)
# Out:
# Unrolled index 0
# 	Inputs:  [0.00086    0.26678938 0.31223807 0.2404593  0.08841562]
#
# 	Output: [0.0040074  0.28859589 0.28231698 0.24528965 0.08363285]
#
#
# Unrolled index 1
# 	Inputs:  [0.00226    0.2705717  0.2957538  0.23977716 0.08363285]
#
# 	Output: [0.0040074  0.31537327 0.2957538  0.25755563 0.07896534]
#
#
# Unrolled index 2
# 	Inputs:  [0.0040074  0.2781573  0.28231698 0.23897493 0.07896534]
#
# 	Output: [0.01126462 0.30114448 0.2567025  0.24528965 0.07439806]
#
#
# Unrolled index 3
# 	Inputs:  [0.00608272 0.28859589 0.27156675 0.24528965 0.07439806]
#
# 	Output: [0.01395409 0.30114448 0.24822608 0.29508626 0.07483398]
#
#
# Unrolled index 4
# 	Inputs:  [0.0085509  0.30114448 0.26318392 0.25755563 0.07316378]
#
# 	Output: [0.01126462 0.31537327 0.251891   0.34235322 0.09377137]

# %%
D = 1 # Dimensionality of the data. Since your data is 1-D this would be 1
num_unrollings = 50 # Number of time steps you look into the future.
batch_size = 500 # Number of samples in a batch
num_nodes = [200,200,150] # Number of hidden nodes in each layer of the deep LSTM stack we're using
n_layers = len(num_nodes) # number of layers
dropout = 0.2 # dropout amount

tf.reset_default_graph() # This is important in case you run this multiple times

# %%
# Input data.
train_inputs, train_outputs = [],[]

# You unroll the input over time defining placeholders for each time step
for ui in range(num_unrollings):
    train_inputs.append(tf.placeholder(tf.float32, shape=[batch_size,D],name='train_inputs_%d'%ui))
    train_outputs.append(tf.placeholder(tf.float32, shape=[batch_size,1], name = 'train_outputs_%d'%ui))

# %%
lstm_cells = [
    tf.contrib.rnn.LSTMCell(num_units=num_nodes[li],
                            state_is_tuple=True,
                            initializer= tf.contrib.layers.xavier_initializer()
                           )
 for li in range(n_layers)]

drop_lstm_cells = [tf.contrib.rnn.DropoutWrapper(
    lstm, input_keep_prob=1.0,output_keep_prob=1.0-dropout, state_keep_prob=1.0-dropout
) for lstm in lstm_cells]
drop_multi_cell = tf.contrib.rnn.MultiRNNCell(drop_lstm_cells)
multi_cell = tf.contrib.rnn.MultiRNNCell(lstm_cells)

w = tf.get_variable('w',shape=[num_nodes[-1], 1], initializer=tf.contrib.layers.xavier_initializer())
b = tf.get_variable('b',initializer=tf.random_uniform([1],-0.1,0.1))
# Out:
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From <ipython-input-64-c24fa21357f4>:6: LSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From <ipython-input-64-c24fa21357f4>:11: MultiRNNCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.StackedRNNCells, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
# Create cell state and hidden state variables to maintain the state of the LSTM
c, h = [],[]
initial_state = []
for li in range(n_layers):
    c.append(tf.Variable(tf.zeros([batch_size, num_nodes[li]]), trainable=False))
    h.append(tf.Variable(tf.zeros([batch_size, num_nodes[li]]), trainable=False))
    initial_state.append(tf.contrib.rnn.LSTMStateTuple(c[li], h[li]))

# Do several tensor transofmations, because the function dynamic_rnn requires the output to be of
# a specific format. Read more at: https://www.tensorflow.org/api_docs/python/tf/nn/dynamic_rnn
all_inputs = tf.concat([tf.expand_dims(t,0) for t in train_inputs],axis=0)

# all_outputs is [seq_length, batch_size, num_nodes]
all_lstm_outputs, state = tf.nn.dynamic_rnn(
    drop_multi_cell, all_inputs, initial_state=tuple(initial_state),
    time_major = True, dtype=tf.float32)

all_lstm_outputs = tf.reshape(all_lstm_outputs, [batch_size*num_unrollings,num_nodes[-1]])

all_outputs = tf.nn.xw_plus_b(all_lstm_outputs,w,b)

split_outputs = tf.split(all_outputs,num_unrollings,axis=0)
# Out:
# WARNING:tensorflow:From <ipython-input-65-e1513a367221>:15: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/rnn_cell_impl.py:1259: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
# When calculating the loss you need to be careful about the exact form, because you calculate
# loss of all the unrolled steps at the same time
# Therefore, take the mean error or each batch and get the sum of that over all the unrolled steps

print('Defining training Loss')
loss = 0.0
with tf.control_dependencies([tf.assign(c[li], state[li][0]) for li in range(n_layers)]+
                             [tf.assign(h[li], state[li][1]) for li in range(n_layers)]):
    for ui in range(num_unrollings):
        loss += tf.reduce_mean(0.5*(split_outputs[ui]-train_outputs[ui])**2)

print('Learning rate decay operations')
global_step = tf.Variable(0, trainable=False)
inc_gstep = tf.assign(global_step,global_step + 1)
tf_learning_rate = tf.placeholder(shape=None,dtype=tf.float32)
tf_min_learning_rate = tf.placeholder(shape=None,dtype=tf.float32)

learning_rate = tf.maximum(
    tf.train.exponential_decay(tf_learning_rate, global_step, decay_steps=1, decay_rate=0.5, staircase=True),
    tf_min_learning_rate)

# Optimizer.
print('TF Optimization operations')
optimizer = tf.train.AdamOptimizer(learning_rate)
gradients, v = zip(*optimizer.compute_gradients(loss))
gradients, _ = tf.clip_by_global_norm(gradients, 5.0)
optimizer = optimizer.apply_gradients(
    zip(gradients, v))

print('\tAll done')
# Out:
# Defining training Loss
# Learning rate decay operations
# TF Optimization operations
# 	All done

# %%
print('Defining prediction related TF functions')

sample_inputs = tf.placeholder(tf.float32, shape=[1,D])

# Maintaining LSTM state for prediction stage
sample_c, sample_h, initial_sample_state = [],[],[]
for li in range(n_layers):
    sample_c.append(tf.Variable(tf.zeros([1, num_nodes[li]]), trainable=False))
    sample_h.append(tf.Variable(tf.zeros([1, num_nodes[li]]), trainable=False))
    initial_sample_state.append(tf.contrib.rnn.LSTMStateTuple(sample_c[li],sample_h[li]))

reset_sample_states = tf.group(*[tf.assign(sample_c[li],tf.zeros([1, num_nodes[li]])) for li in range(n_layers)],
                               *[tf.assign(sample_h[li],tf.zeros([1, num_nodes[li]])) for li in range(n_layers)])

sample_outputs, sample_state = tf.nn.dynamic_rnn(multi_cell, tf.expand_dims(sample_inputs,0),
                                   initial_state=tuple(initial_sample_state),
                                   time_major = True,
                                   dtype=tf.float32)

with tf.control_dependencies([tf.assign(sample_c[li],sample_state[li][0]) for li in range(n_layers)]+
                              [tf.assign(sample_h[li],sample_state[li][1]) for li in range(n_layers)]):  
    sample_prediction = tf.nn.xw_plus_b(tf.reshape(sample_outputs,[1,-1]), w, b)

print('\tAll done')
# Out:
# Defining prediction related TF functions
# 	All done

# %%
epochs = 30
valid_summary = 1 # Interval you make test predictions

n_predict_once = 50 # Number of steps you continously predict for

train_seq_length = train_data.size # Full length of the training data

train_mse_ot = [] # Accumulate Train losses
test_mse_ot = [] # Accumulate Test loss
predictions_over_time = [] # Accumulate predictions

session = tf.InteractiveSession()

tf.global_variables_initializer().run()

# Used for decaying learning rate
loss_nondecrease_count = 0
loss_nondecrease_threshold = 2 # If the test error hasn't increased in this many steps, decrease learning rate

print('Initialized')
average_loss = 0

# Define data generator
data_gen = DataGeneratorSeq(train_data,batch_size,num_unrollings)

x_axis_seq = []

# Points you start your test predictions from
test_points_seq = np.arange(8000,8700,50).tolist()

for ep in range(epochs):       

    # ========================= Training =====================================
    for step in range(train_seq_length//batch_size):

        u_data, u_labels = data_gen.unroll_batches()

        feed_dict = {}
        for ui,(dat,lbl) in enumerate(zip(u_data,u_labels)):            
            feed_dict[train_inputs[ui]] = dat.reshape(-1,1)
            feed_dict[train_outputs[ui]] = lbl.reshape(-1,1)

        feed_dict.update({tf_learning_rate: 0.0001, tf_min_learning_rate:0.000001})

        _, l = session.run([optimizer, loss], feed_dict=feed_dict)

        average_loss += l

    # ============================ Validation ==============================
    if (ep+1) % valid_summary == 0:

        average_loss = average_loss/(valid_summary*(train_seq_length//batch_size))

        # The average loss
        if (ep+1)%valid_summary==0:
            print('Average loss at step %d: %f' % (ep+1, average_loss))

        train_mse_ot.append(average_loss)

        average_loss = 0 # reset loss

        predictions_seq = []

        mse_test_loss_seq = []

      # ===================== Updating State and Making Predicitons ========================
        for w_i in test_points_seq:
            mse_test_loss = 0.0
            our_predictions = []

        if (ep+1)-valid_summary==0:
          # Only calculate x_axis values in the first validation epoch
          x_axis=[]

        # Feed in the recent past behavior of stock prices
        # to make predictions from that point onwards
        for tr_i in range(w_i-num_unrollings+1,w_i-1):
            current_price = all_mid_data[tr_i]
            feed_dict[sample_inputs] = np.array(current_price).reshape(1,1)    
            _ = session.run(sample_prediction,feed_dict=feed_dict)

        feed_dict = {}

        current_price = all_mid_data[w_i-1]

        feed_dict[sample_inputs] = np.array(current_price).reshape(1,1)

        # Make predictions for this many steps
        # Each prediction uses previous prediciton as it's current input
        for pred_i in range(n_predict_once):

            pred = session.run(sample_prediction,feed_dict=feed_dict)

            our_predictions.append(np.asscalar(pred))

            feed_dict[sample_inputs] = np.asarray(pred).reshape(-1,1)

            if (ep+1)-valid_summary==0:
                # Only calculate x_axis values in the first validation epoch
                x_axis.append(w_i+pred_i)

            mse_test_loss += 0.5*(pred-all_mid_data[w_i+pred_i])**2

            session.run(reset_sample_states)

            predictions_seq.append(np.array(our_predictions))

            mse_test_loss /= n_predict_once
            mse_test_loss_seq.append(mse_test_loss)

            if (ep+1)-valid_summary==0:
                x_axis_seq.append(x_axis)

            current_test_mse = np.mean(mse_test_loss_seq)

            # Learning rate decay logic
            if len(test_mse_ot)>0 and current_test_mse > min(test_mse_ot):
                loss_nondecrease_count += 1
            else:
                loss_nondecrease_count = 0

            if loss_nondecrease_count > loss_nondecrease_threshold :
                session.run(inc_gstep)
                loss_nondecrease_count = 0
                print('\tDecreasing learning rate by 0.5')

            test_mse_ot.append(current_test_mse)
            print('\tTest MSE: %.5f'%np.mean(mse_test_loss_seq))
            predictions_over_time.append(predictions_seq)
            print('\tFinished Predictions')
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py:1702: UserWarning: An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
#   warnings.warn('An interactive session is already active. This can '
# Initialized
# Average loss at step 1: 2.710948
# 	Test MSE: 1.28291
# 	Finished Predictions
# 	Test MSE: 1.97616
# 	Finished Predictions
# 	Test MSE: 1.89951
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.95017
# 	Finished Predictions
# 	Test MSE: 1.82207
# 	Finished Predictions
# 	Test MSE: 1.88282
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.90994
# 	Finished Predictions
# 	Test MSE: 1.95591
# 	Finished Predictions
# 	Test MSE: 2.06068
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 2.03161
# 	Finished Predictions
# 	Test MSE: 2.30209
# 	Finished Predictions
# 	Test MSE: 2.11479
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.97527
# 	Finished Predictions
# 	Test MSE: 1.95999
# 	Finished Predictions
# 	Test MSE: 1.90738
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.87096
# 	Finished Predictions
# 	Test MSE: 1.80982
# 	Finished Predictions
# 	Test MSE: 1.77943
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.84008
# 	Finished Predictions
# 	Test MSE: 1.81320
# 	Finished Predictions
# 	Test MSE: 1.65632
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.60267
# 	Finished Predictions
# 	Test MSE: 1.50783
# 	Finished Predictions
# 	Test MSE: 1.64958
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.71213
# 	Finished Predictions
# 	Test MSE: 1.69013
# 	Finished Predictions
# 	Test MSE: 1.59584
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.57340
# 	Finished Predictions
# 	Test MSE: 1.50846
# 	Finished Predictions
# 	Test MSE: 1.52544
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.79699
# 	Finished Predictions
# 	Test MSE: 1.70749
# 	Finished Predictions
# 	Test MSE: 1.70570
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.66839
# 	Finished Predictions
# 	Test MSE: 1.55523
# 	Finished Predictions
# 	Test MSE: 1.61465
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.58490
# 	Finished Predictions
# 	Test MSE: 1.53327
# 	Finished Predictions
# 	Test MSE: 1.54329
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.59308
# 	Finished Predictions
# 	Test MSE: 1.73068
# 	Finished Predictions
# 	Test MSE: 1.75042
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.80760
# 	Finished Predictions
# Average loss at step 18: 0.284988
# 	Test MSE: 1.33908
# 	Finished Predictions
# 	Test MSE: 1.97770
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.89973
# 	Finished Predictions
# 	Test MSE: 1.95037
# 	Finished Predictions
# 	Test MSE: 1.82226
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.88301
# 	Finished Predictions
# 	Test MSE: 1.91014
# 	Finished Predictions
# 	Test MSE: 1.95611
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 2.06088
# 	Finished Predictions
# 	Test MSE: 2.03182
# 	Finished Predictions
# 	Test MSE: 2.30231
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 2.11500
# 	Finished Predictions
# 	Test MSE: 1.97547
# 	Finished Predictions
# 	Test MSE: 1.96019
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.90758
# 	Finished Predictions
# 	Test MSE: 1.87116
# 	Finished Predictions
# 	Test MSE: 1.81001
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.77962
# 	Finished Predictions
# 	Test MSE: 1.84028
# 	Finished Predictions
# 	Test MSE: 1.81339
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.65650
# 	Finished Predictions
# 	Test MSE: 1.60285
# 	Finished Predictions
# 	Test MSE: 1.50800
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.64976
# 	Finished Predictions
# 	Test MSE: 1.71231
# 	Finished Predictions
# 	Test MSE: 1.69032
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.59602
# 	Finished Predictions
# 	Test MSE: 1.57358
# 	Finished Predictions
# 	Test MSE: 1.50863
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.52562
# 	Finished Predictions
# 	Test MSE: 1.53269
# 	Finished Predictions
# 	Test MSE: 1.60916
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.57570
# 	Finished Predictions
# 	Test MSE: 1.56140
# 	Finished Predictions
# 	Test MSE: 1.48780
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.57576
# 	Finished Predictions
# 	Test MSE: 1.71862
# 	Finished Predictions
# 	Test MSE: 1.79699
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.70749
# 	Finished Predictions
# 	Test MSE: 1.70570
# 	Finished Predictions
# 	Test MSE: 1.66838
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.55522
# 	Finished Predictions
# 	Test MSE: 1.61465
# 	Finished Predictions
# 	Test MSE: 1.58490
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.53327
# 	Finished Predictions
# 	Test MSE: 1.54328
# 	Finished Predictions
# 	Test MSE: 1.59308
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.73067
# 	Finished Predictions
# 	Test MSE: 1.75041
# 	Finished Predictions
# 	Test MSE: 1.80760
# 	Finished Predictions
# Average loss at step 19: 0.289778
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.33687
# 	Finished Predictions
# 	Test MSE: 1.97763
# 	Finished Predictions
# 	Test MSE: 1.89973
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.95036
# ...
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.73066
# 	Finished Predictions
# 	Test MSE: 1.75040
# 	Finished Predictions
# 	Test MSE: 1.80758
# 	Finished Predictions
# Average loss at step 25: 0.279496
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.32472
# 	Finished Predictions
# 	Test MSE: 1.97725
# 	Finished Predictions
# 	Test MSE: 1.89971
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.95035
# 	Finished Predictions
# 	Test MSE: 1.82225
# 	Finished Predictions
# 	Test MSE: 1.88300
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.91012
# 	Finished Predictions
# 	Test MSE: 1.95610
# 	Finished Predictions
# 	Test MSE: 2.06087
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 2.03180
# 	Finished Predictions
# 	Test MSE: 2.30229
# 	Finished Predictions
# 	Test MSE: 2.11498
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.97546
# 	Finished Predictions
# 	Test MSE: 1.96017
# 	Finished Predictions
# 	Test MSE: 1.90757
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.87114
# 	Finished Predictions
# 	Test MSE: 1.81000
# 	Finished Predictions
# 	Test MSE: 1.77960
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.84026
# 	Finished Predictions
# 	Test MSE: 1.81338
# 	Finished Predictions
# 	Test MSE: 1.65649
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.60284
# 	Finished Predictions
# 	Test MSE: 1.50799
# 	Finished Predictions
# 	Test MSE: 1.64975
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.71230
# 	Finished Predictions
# 	Test MSE: 1.69031
# 	Finished Predictions
# 	Test MSE: 1.59601
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.57357
# 	Finished Predictions
# 	Test MSE: 1.50862
# 	Finished Predictions
# 	Test MSE: 1.52561
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.53268
# 	Finished Predictions
# 	Test MSE: 1.60915
# 	Finished Predictions
# 	Test MSE: 1.57569
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.56139
# 	Finished Predictions
# 	Test MSE: 1.48779
# 	Finished Predictions
# 	Test MSE: 1.57575
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.71861
# 	Finished Predictions
# 	Test MSE: 1.79697
# 	Finished Predictions
# 	Test MSE: 1.70748
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.70569
# 	Finished Predictions
# 	Test MSE: 1.66837
# 	Finished Predictions
# 	Test MSE: 1.55521
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.61464
# 	Finished Predictions
# 	Test MSE: 1.58488
# 	Finished Predictions
# 	Test MSE: 1.53325
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.54327
# 	Finished Predictions
# 	Test MSE: 1.59307
# 	Finished Predictions
# 	Test MSE: 1.73066
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.75040
# 	Finished Predictions
# 	Test MSE: 1.80758
# 	Finished Predictions
# Average loss at step 26: 0.281398
# 	Test MSE: 1.32269
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.97719
# 	Finished Predictions
# 	Test MSE: 1.89971
# 	Finished Predictions
# 	Test MSE: 1.95035
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.82225
# 	Finished Predictions
# 	Test MSE: 1.88300
# 	Finished Predictions
# 	Test MSE: 1.91012
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.95609
# 	Finished Predictions
# 	Test MSE: 2.06086
# 	Finished Predictions
# 	Test MSE: 2.03180
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 2.30229
# 	Finished Predictions
# 	Test MSE: 2.11498
# 	Finished Predictions
# 	Test MSE: 1.97546
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.96017
# 	Finished Predictions
# 	Test MSE: 1.90756
# 	Finished Predictions
# 	Test MSE: 1.87114
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.80999
# 	Finished Predictions
# 	Test MSE: 1.77960
# 	Finished Predictions
# 	Test MSE: 1.84026
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.81337
# 	Finished Predictions
# 	Test MSE: 1.65649
# 	Finished Predictions
# 	Test MSE: 1.60284
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.50799
# 	Finished Predictions
# 	Test MSE: 1.64975
# 	Finished Predictions
# 	Test MSE: 1.71230
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.69031
# 	Finished Predictions
# 	Test MSE: 1.59601
# 	Finished Predictions
# 	Test MSE: 1.57356
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.50862
# 	Finished Predictions
# 	Test MSE: 1.52561
# 	Finished Predictions
# 	Test MSE: 1.53268
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.60914
# 	Finished Predictions
# 	Test MSE: 1.57569
# 	Finished Predictions
# 	Test MSE: 1.56138
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.48779
# 	Finished Predictions
# 	Test MSE: 1.57575
# 	Finished Predictions
# 	Test MSE: 1.71860
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.79697
# 	Finished Predictions
# 	Test MSE: 1.70748
# 	Finished Predictions
# 	Test MSE: 1.70569
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.66837
# 	Finished Predictions
# 	Test MSE: 1.55521
# 	Finished Predictions
# 	Test MSE: 1.61464
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.58488
# 	Finished Predictions
# 	Test MSE: 1.53325
# 	Finished Predictions
# 	Test MSE: 1.54327
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.59306
# 	Finished Predictions
# 	Test MSE: 1.73066
# 	Finished Predictions
# 	Test MSE: 1.75040
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.80758
# 	Finished Predictions
# Average loss at step 27: 0.277706
# 	Test MSE: 1.32061
# 	Finished Predictions
# 	Test MSE: 1.97713
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.89970
# 	Finished Predictions
# 	Test MSE: 1.95035
# 	Finished Predictions
# 	Test MSE: 1.82224
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.88300
# 	Finished Predictions
# 	Test MSE: 1.91012
# 	Finished Predictions
# 	Test MSE: 1.95609
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 2.06086
# 	Finished Predictions
# 	Test MSE: 2.03180
# 	Finished Predictions
# 	Test MSE: 2.30229
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 2.11498
# 	Finished Predictions
# 	Test MSE: 1.97545
# 	Finished Predictions
# 	Test MSE: 1.96017
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.90756
# 	Finished Predictions
# 	Test MSE: 1.87114
# 	Finished Predictions
# 	Test MSE: 1.80999
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.77960
# 	Finished Predictions
# 	Test MSE: 1.84026
# 	Finished Predictions
# 	Test MSE: 1.81337
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.65649
# 	Finished Predictions
# 	Test MSE: 1.60283
# 	Finished Predictions
# 	Test MSE: 1.50799
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.64974
# 	Finished Predictions
# 	Test MSE: 1.71230
# 	Finished Predictions
# 	Test MSE: 1.69030
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.59600
# 	Finished Predictions
# 	Test MSE: 1.57356
# 	Finished Predictions
# 	Test MSE: 1.50862
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.52560
# 	Finished Predictions
# 	Test MSE: 1.53268
# 	Finished Predictions
# 	Test MSE: 1.60914
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.57569
# 	Finished Predictions
# 	Test MSE: 1.56138
# 	Finished Predictions
# 	Test MSE: 1.48778
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.57575
# 	Finished Predictions
# 	Test MSE: 1.71860
# 	Finished Predictions
# 	Test MSE: 1.79697
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.70747
# 	Finished Predictions
# 	Test MSE: 1.70568
# 	Finished Predictions
# 	Test MSE: 1.66837
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.55521
# 	Finished Predictions
# 	Test MSE: 1.61463
# 	Finished Predictions
# 	Test MSE: 1.58488
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.53325
# 	Finished Predictions
# 	Test MSE: 1.54327
# 	Finished Predictions
# 	Test MSE: 1.59306
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.73066
# 	Finished Predictions
# 	Test MSE: 1.75040
# 	Finished Predictions
# 	Test MSE: 1.80758
# 	Finished Predictions
# Average loss at step 28: 0.272415
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.31830
# 	Finished Predictions
# 	Test MSE: 1.97705
# 	Finished Predictions
# 	Test MSE: 1.89970
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.95034
# 	Finished Predictions
# 	Test MSE: 1.82224
# 	Finished Predictions
# 	Test MSE: 1.88299
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.91012
# 	Finished Predictions
# 	Test MSE: 1.95609
# 	Finished Predictions
# 	Test MSE: 2.06086
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 2.03179
# 	Finished Predictions
# 	Test MSE: 2.30228
# 	Finished Predictions
# 	Test MSE: 2.11498
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.97545
# 	Finished Predictions
# 	Test MSE: 1.96017
# 	Finished Predictions
# 	Test MSE: 1.90756
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.87114
# 	Finished Predictions
# 	Test MSE: 1.80999
# 	Finished Predictions
# 	Test MSE: 1.77960
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.84026
# 	Finished Predictions
# 	Test MSE: 1.81337
# 	Finished Predictions
# 	Test MSE: 1.65648
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.60283
# 	Finished Predictions
# 	Test MSE: 1.50798
# 	Finished Predictions
# 	Test MSE: 1.64974
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.71229
# 	Finished Predictions
# 	Test MSE: 1.69030
# 	Finished Predictions
# 	Test MSE: 1.59600
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.57356
# 	Finished Predictions
# 	Test MSE: 1.50861
# 	Finished Predictions
# 	Test MSE: 1.52560
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.53268
# 	Finished Predictions
# 	Test MSE: 1.60914
# 	Finished Predictions
# 	Test MSE: 1.57568
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.56138
# 	Finished Predictions
# 	Test MSE: 1.48778
# 	Finished Predictions
# 	Test MSE: 1.57574
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.71860
# 	Finished Predictions
# 	Test MSE: 1.79697
# 	Finished Predictions
# 	Test MSE: 1.70747
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.70568
# 	Finished Predictions
# 	Test MSE: 1.66836
# 	Finished Predictions
# 	Test MSE: 1.55520
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.61463
# 	Finished Predictions
# 	Test MSE: 1.58488
# 	Finished Predictions
# 	Test MSE: 1.53325
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.54326
# 	Finished Predictions
# 	Test MSE: 1.59306
# 	Finished Predictions
# 	Test MSE: 1.73065
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.75039
# 	Finished Predictions
# 	Test MSE: 1.80757
# 	Finished Predictions
# Average loss at step 29: 0.275200
# 	Test MSE: 1.31587
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.97698
# 	Finished Predictions
# 	Test MSE: 1.89969
# 	Finished Predictions
# 	Test MSE: 1.95034
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.82224
# 	Finished Predictions
# 	Test MSE: 1.88299
# 	Finished Predictions
# 	Test MSE: 1.91011
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.95608
# 	Finished Predictions
# 	Test MSE: 2.06085
# 	Finished Predictions
# 	Test MSE: 2.03179
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 2.30228
# 	Finished Predictions
# 	Test MSE: 2.11497
# 	Finished Predictions
# 	Test MSE: 1.97545
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.96016
# 	Finished Predictions
# 	Test MSE: 1.90755
# 	Finished Predictions
# 	Test MSE: 1.87113
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.80999
# 	Finished Predictions
# 	Test MSE: 1.77959
# 	Finished Predictions
# 	Test MSE: 1.84025
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.81336
# 	Finished Predictions
# 	Test MSE: 1.65648
# 	Finished Predictions
# 	Test MSE: 1.60283
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.50798
# 	Finished Predictions
# 	Test MSE: 1.64974
# 	Finished Predictions
# 	Test MSE: 1.71229
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.69030
# 	Finished Predictions
# 	Test MSE: 1.59600
# 	Finished Predictions
# 	Test MSE: 1.57356
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.50861
# 	Finished Predictions
# 	Test MSE: 1.52560
# 	Finished Predictions
# 	Test MSE: 1.53267
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.60914
# 	Finished Predictions
# 	Test MSE: 1.57568
# 	Finished Predictions
# 	Test MSE: 1.56138
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.48778
# 	Finished Predictions
# 	Test MSE: 1.57574
# 	Finished Predictions
# 	Test MSE: 1.71859
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.79696
# 	Finished Predictions
# 	Test MSE: 1.70747
# 	Finished Predictions
# 	Test MSE: 1.70568
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.66836
# 	Finished Predictions
# 	Test MSE: 1.55520
# 	Finished Predictions
# 	Test MSE: 1.61463
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.58487
# 	Finished Predictions
# 	Test MSE: 1.53324
# 	Finished Predictions
# 	Test MSE: 1.54326
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.59306
# 	Finished Predictions
# 	Test MSE: 1.73065
# 	Finished Predictions
# 	Test MSE: 1.75039
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.80757
# 	Finished Predictions
# Average loss at step 30: 0.275857
# 	Test MSE: 1.31371
# 	Finished Predictions
# 	Test MSE: 1.97691
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.89969
# 	Finished Predictions
# 	Test MSE: 1.95034
# 	Finished Predictions
# 	Test MSE: 1.82223
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.88299
# 	Finished Predictions
# 	Test MSE: 1.91011
# 	Finished Predictions
# 	Test MSE: 1.95608
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 2.06085
# 	Finished Predictions
# 	Test MSE: 2.03179
# 	Finished Predictions
# 	Test MSE: 2.30228
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 2.11497
# 	Finished Predictions
# 	Test MSE: 1.97544
# 	Finished Predictions
# 	Test MSE: 1.96016
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.90755
# 	Finished Predictions
# 	Test MSE: 1.87113
# 	Finished Predictions
# 	Test MSE: 1.80998
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.77959
# 	Finished Predictions
# 	Test MSE: 1.84025
# 	Finished Predictions
# 	Test MSE: 1.81336
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.65648
# 	Finished Predictions
# 	Test MSE: 1.60283
# 	Finished Predictions
# 	Test MSE: 1.50798
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.64973
# 	Finished Predictions
# 	Test MSE: 1.71229
# 	Finished Predictions
# 	Test MSE: 1.69029
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.59599
# 	Finished Predictions
# 	Test MSE: 1.57355
# 	Finished Predictions
# 	Test MSE: 1.50861
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.52560
# 	Finished Predictions
# 	Test MSE: 1.53267
# 	Finished Predictions
# 	Test MSE: 1.60913
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.57568
# 	Finished Predictions
# 	Test MSE: 1.56137
# 	Finished Predictions
# 	Test MSE: 1.48778
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.57574
# 	Finished Predictions
# 	Test MSE: 1.71859
# 	Finished Predictions
# 	Test MSE: 1.79696
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.70747
# 	Finished Predictions
# 	Test MSE: 1.70568
# 	Finished Predictions
# 	Test MSE: 1.66836
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.55520
# 	Finished Predictions
# 	Test MSE: 1.61463
# 	Finished Predictions
# 	Test MSE: 1.58487
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.53324
# 	Finished Predictions
# 	Test MSE: 1.54326
# 	Finished Predictions
# 	Test MSE: 1.59305
# 	Finished Predictions
# 	Decreasing learning rate by 0.5
# 	Test MSE: 1.73065
# 	Finished Predictions
# 	Test MSE: 1.75039
# 	Finished Predictions
# 	Test MSE: 1.80757
# 	Finished Predictions

# %%
best_prediction_epoch = 28 # replace this with the epoch that you got the best results when running the plotting code

plt.figure(figsize = (18,18))
plt.subplot(2,1,1)
plt.plot(range(df.shape[0]),all_mid_data,color='b')

# Plotting how the predictions change over time
# Plot older predictions with low alpha and newer predictions with high alpha
start_alpha = 0.25
alpha  = np.arange(start_alpha,1.1,(1.0-start_alpha)/len(predictions_over_time[::3]))
for p_i,p in enumerate(predictions_over_time[::3]):
    for xval,yval in zip(x_axis_seq,p):
        plt.plot(xval,yval,color='r',alpha=alpha[p_i])

plt.title('Evolution of Test Predictions Over Time',fontsize=18)
plt.xlabel('Date',fontsize=18)
plt.ylabel('Mid Price',fontsize=18)
plt.xlim(8000,8700)

plt.subplot(2,1,2)

'''# Predicting the best test prediction you got
plt.plot(range(df.shape[0]),all_mid_data,color='b')
for xval,yval in zip(x_axis_seq,predictions_over_time[best_prediction_epoch]):
    plt.plot(xval,yval,color='r')

plt.title('Best Test Predictions Over Time',fontsize=18)
plt.xlabel('Date',fontsize=18)
plt.ylabel('Mid Price',fontsize=18)
plt.xlim(8000,8700)'''
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-76-c7108d96b415> in <module>()
#      11 for p_i,p in enumerate(predictions_over_time[::3]):
#      12     for xval,yval in zip(x_axis_seq,p):
# ---> 13         plt.plot(xval,yval,color='r',alpha=alpha[p_i])
#      14
#      15 plt.title('Evolution of Test Predictions Over Time',fontsize=18)
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2809     return gca().plot(
#    2810         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2811         is not None else {}), **kwargs)
#    2812
#    2813
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, *args, **kwargs)
#    1609         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
#    1610
# -> 1611         for line in self._get_lines(*args, **kwargs):
#    1612             self.add_line(line)
#    1613             lines.append(line)
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_base.py in _grab_next_args(self, *args, **kwargs)
#     391                 this += args[0],
#     392                 args = args[1:]
# --> 393             yield from self._plot_args(this, kwargs)
#     394
#     395
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     368             x, y = index_of(tup[-1])
#     369
# --> 370         x, y = self._xy_from_xy(x, y)
#     371
#     372         if self.command == 'plot':
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_base.py in _xy_from_xy(self, x, y)
#     229         if x.shape[0] != y.shape[0]:
#     230             raise ValueError("x and y must have same first dimension, but "
# --> 231                              "have shapes {} and {}".format(x.shape, y.shape))
#     232         if x.ndim > 2 or y.ndim > 2:
#     233             raise ValueError("x and y can be no greater than 2-D, but have "
#
# ValueError: x and y must have same first dimension, but have shapes (50,) and (1,)
